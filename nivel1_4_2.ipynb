# %% [markdown]
# <center><img src="https://media-exp1.licdn.com/dms/image/C4E22AQEbIXZiRVkJPQ/feedshare-shrink_2048_1536/0?e=1602115200&v=beta&t=XHE3KbzKbKy54WYDTfq7VFNUPfNjoIOrjBw6dzFPTfA" width="1000"></center>

# %% [markdown]
# # SDC Certified Program in Python for Data Analysis
#
# ## Tema 4.2. Datos en la web
#
# ### Prof. Manuel Sigüeñas, M.Sc.(c)
#
# [Perfil](https://socialdata-peru.com/learning/teacher2.php)
#
# ### Prof. Lenguajes de Programación para Ciencia de Datos / Agile Data Scientists / SCRUMStudy Certified Trainer
#
#
# [msiguenas@socialdata-peru.com](msiguenas@socialdata-peru.com)

# %%
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# 1. [Datos que forman parte de una página web](#part1)
# 2. [Casos Propuestos](#part2)

# %% [markdown]
# <a id='part1'></a>
# ### 1. Datos que forman parte de una página web

# %% [markdown]
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>
#           un mini ejemplo
#         </title>
#     </head>
#     <body>
#         <div id="date"> Fecha 30/09/2019 </div>
#         <div id="content"> clase de web scraping </div>
#     </body>
#     <body>
#         <div id="date"> Fecha 01/10/2019 </div>
#         <div id="content"> trabajar </div>
#     </body>
#     <body>
#         <div id="date"> Fecha 02/10/2019 </div>
#         <div id="content"> celebrar </div>
#     </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>: indica que se trata de un documento html

# %% [markdown]
# abre <html> y cierra  </html>

# %% [markdown]
# <head> _ </head>: describe la cabecera del documento, como puede ser su título, el autor, etc.

# %%
<body> _ </body>: es el contenido en sí de la página que es lo que nosotros deseamos examninar.

# %% [markdown]
# <a id='part2'></a>
# ### 2.  Casos Propuestos

# %% [markdown]
# ##### a.	Bumeran

# %% [markdown]
# Es una empresa que se encarga de proporcionar clasificados de trabajo a lo largo de toda Latinoamérica, es considerada una de las más importantes actualmente en el área de conseguir empleo por medio de esta plataforma.
#
# Para este caso usaremos la página de Bumeran para Perú, desde el siguiente link:
# https://www.bumeran.com.pe/jesus-maria-lima/empleos.html

# %%
Image(filename='D:/Python/web_scraping/imagenes/bumeran.png', width=400)

# %% [markdown]
# Se extrae el código contenedor, en este caso es el class “aviso-no-sponsor”

# %%
Image(filename='D:/Python/web_scraping/imagenes/codigo bumeran 1.png', width=400)

# %% [markdown]
# Luego se debe encontrar y extraer los datos, por medio de sus “class” únicos.

# %%
Image(filename='D:/Python/web_scraping/imagenes/codigo bumeran 2.png', width=400)

# %% [markdown]
# ##### b.	Buscalibre

# %% [markdown]
# Es una plataforma de venta de libros online a nivel de Hispanoamérica. En este caso se desea obtener la lista de los nombres y precios de los libros.
#
# https://www.buscalibre.pe/libros/search?q=big+data&page=

# %%
Image(filename='D:/Python/web_scraping/imagenes/buscalibre.png', width=400)

# %% [markdown]
# Para este caso, los códigos son mas explícitos. Estando separados intuitivamente

# %%
Image(filename='D:/Python/web_scraping/imagenes/buscalibre codigo.png', width=400)

# %% [markdown]
# ##### c.	El congreso

# %% [markdown]
# El congreso en su función legislativa; propone, archiva, modifica, aprueba. Entonces, para este caso se extraerá una lista de los últimos proyectos de ley, desde la siguiente página del congreso:
#
# http://www2.congreso.gob.pe/Sicr/TraDocEstProc/CLProLey2016.nsf/Local%20Por%20Numero%20Inverso?OpenView

# %% [markdown]
# Para todos los casos se debe inspeccionar el código fuente Y reconocer ¿Qué es lo que se desea extraer? En este caso se desea extraer una tabla.

# %%
Image(filename='D:/Python/web_scraping/imagenes/proyectos.png', width=400)

# %% [markdown]
# El nodo por extraer, en este caso es el de “table”.

# %%
Image(filename='D:/Python/web_scraping/imagenes/Codigo_congreso.png', width=400)
